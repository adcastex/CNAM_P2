# %%
import pandas as pd

# %%
df=pd.read_excel("data/Cartographie des mutualisations.xlsx",sheet_name="Fiche CP Mutualisées")

# %%
df
# Out:
#     Référentiel  des mutualisations structurées par processus d'activités et par Caisse Prenante   -   2023/10  \
# 0                                          Le 10/11/23
# 1                                                  NaN
# 2                                                  NaN
# 3                                   Caisse CC-CP-CC&CP
# 4                                                  NaN
# ..                                                 ...
# 383                                 EPTICA - Délestage
# 384                                 EPTICA - Délestage
# 385                                 EPTICA - Délestage
# 386                                                NaN
# 387                           PHARE - RDV Téléphonique
#
#                                             Unnamed: 1     Unnamed: 2  \
# 0    ETP mobilisés (Hors DOM et CRAMIF) : Source DA...            NaN
# 1                                                  NaN            NaN
# ...

# %%
df.drop(index=[0,1,2,3,4,5],inplace=True)

# %%
df.columns = df.iloc[0]
df = df[1:]
df
# Out:
# 6     Catégorie Mutualisation          Sous-Dispositif Caisse Code  \
# 7             EPTICA - Centre  Mutualisation Régionale         171
# 8             EPTICA - Centre  Mutualisation Régionale         251
# 9             EPTICA - Centre  Mutualisation Régionale         311
# 10            EPTICA - Centre  Mutualisation Régionale         351
# 11            EPTICA - Centre  Mutualisation Régionale         401
# ..                        ...                      ...         ...
# 383        EPTICA - Délestage  Mutualisation Régionale         111
# 384        EPTICA - Délestage  Mutualisation Régionale         673
# 385        EPTICA - Délestage  Mutualisation Régionale         771
# 386                       NaN                      NaN         NaN
# 387  PHARE - RDV Téléphonique                    PHARE          81
#
# 6               Caisse Libellé Département Code Département Libellé  \
# 7             CPAM LA ROCHELLE               17   Charente Maritime
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df = df.dropna(subset=["Liste des Caisses aidées"])

# %%
df
# Out:
# 6   Catégorie Mutualisation          Sous-Dispositif Caisse Code  \
# 0           EPTICA - Centre  Mutualisation Régionale         171
# 1           EPTICA - Centre  Mutualisation Régionale         251
# 2           EPTICA - Centre  Mutualisation Régionale         311
# 3           EPTICA - Centre  Mutualisation Régionale         351
# 4           EPTICA - Centre  Mutualisation Régionale         401
# ..                      ...                      ...         ...
# 373           TRAM - Rentes  Mutualisation Régionale         881
# 374           TRAM - Rentes  Mutualisation Régionale         921
# 376      EPTICA - Délestage  Mutualisation Régionale         111
# 377      EPTICA - Délestage  Mutualisation Régionale         673
# 378      EPTICA - Délestage  Mutualisation Régionale         771
#
# 6         Caisse Libellé Département Code Département Libellé Région Code  \
# 0       CPAM LA ROCHELLE               17   Charente Maritime         NAQ
# ...

# %%
df = df.loc[df["Caisse Code"] != df["Liste des Caisses aidées"]]

# %%
df
# Out:
# 6   Catégorie Mutualisation          Sous-Dispositif Caisse Code  \
# 0           EPTICA - Centre  Mutualisation Régionale         171
# 1           EPTICA - Centre  Mutualisation Régionale         251
# 2           EPTICA - Centre  Mutualisation Régionale         311
# 3           EPTICA - Centre  Mutualisation Régionale         351
# 4           EPTICA - Centre  Mutualisation Régionale         401
# ..                      ...                      ...         ...
# 373           TRAM - Rentes  Mutualisation Régionale         881
# 374           TRAM - Rentes  Mutualisation Régionale         921
# 376      EPTICA - Délestage  Mutualisation Régionale         111
# 377      EPTICA - Délestage  Mutualisation Régionale         673
# 378      EPTICA - Délestage  Mutualisation Régionale         771
#
# 6         Caisse Libellé Département Code Département Libellé Région Code  \
# 0       CPAM LA ROCHELLE               17   Charente Maritime         NAQ
# ...

# %%
print(df.index[376])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/adriencastex/Documents/Adrien/Cours/CNAM/CNAM_P2/RegroupementCPAM.ipynb Cellule 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/adriencastex/Documents/Adrien/Cours/CNAM/CNAM_P2/RegroupementCPAM.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> print(df.index[376])
#
# File ~/Documents/Adrien/Cours/CNAM/envCNAM/lib/python3.9/site-packages/pandas/core/indexes/base.py:5365, in Index.__getitem__(self, key)
#    5362 if is_integer(key) or is_float(key):
#    5363     # GH#44051 exclude bool, which would return a 2d ndarray
#    5364     key = com.cast_scalar_indexer(key)
# -> 5365     return getitem(key)
#    5367 if isinstance(key, slice):
#    5368     # This case is separated from the conditional above to avoid
#    5369     # pessimization com.is_bool_indexer and ndim checks.
#    5370     return self._getitem_slice(key)
#
# ...
